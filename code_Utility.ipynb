# %%
from Capstone_Group6_Utility import *

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Analysis of Red Wine Quality
# Group Member:
# Jiajing Cai,
# Zhenghao Deng,
# Xinhang Li

# %% [markdown]
# # Section 1 - Data Extraction and Cleansing

# %%
wine_df = read_csv('winequality-red.csv')
print(wine_df.shape)
wine_df.head()
# Out:
# (1599, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4      5.0
# 1      9.8      5.0
# ...

# %%
data_cleansing(wine_df)
print('')
print(wine_df.shape)
wine_df.head()
# Out:
# Check null and missing values in the dataframe and the result is:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
#
# (1359, 12)
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %%
wine_df['quality'].value_counts().plot.bar()
plt.ylabel('Counts')
plt.xlabel('Quality')
plt.xticks(rotation=0)
plt.title('Quality of Red wine')
# Out:
# Text(0.5, 1.0, 'Quality of Red wine')

# %% [markdown]
# # Section 2 - Modeling

# %%
X_train, X_test, Y_train, Y_test = split_set(wine_df)

# %%
print("The training set: ")
X_train
# Out:
# The training set:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1451            7.8             0.320         0.44             2.7      0.104
# 1095            9.4             0.400         0.47             2.5      0.087
# 834             8.8             0.685         0.26             1.6      0.088
# 1438            7.0             0.590         0.00             1.7      0.052
# 808             7.4             0.530         0.12             1.9      0.165
# ...             ...               ...          ...             ...        ...
# 338            12.4             0.490         0.58             3.0      0.103
# 742             6.5             0.615         0.00             1.9      0.065
# 1571            6.4             0.380         0.14             2.2      0.038
# 738             9.0             0.460         0.23             2.8      0.092
# 1414           10.0             0.320         0.59             2.2      0.077
#
# ...

# %%
print("\nThe testing set: ")
X_test
# Out:
# The testing set:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 177             7.5              0.52         0.42             2.3      0.087
# 1556            6.6              0.88         0.04             2.2      0.066
# 1448            6.9              0.58         0.01             1.9      0.080
# 781             6.5              0.46         0.14             2.4      0.114
# 1532            7.2              0.53         0.13             2.0      0.058
# ...             ...               ...          ...             ...        ...
# 1538            6.2              0.64         0.09             2.5      0.081
# 110             7.8              0.56         0.19             1.8      0.104
# 133             6.6              0.50         0.01             1.5      0.060
# 882             8.4              0.31         0.29             3.1      0.194
# 192             6.8              0.63         0.12             3.8      0.099
#
# ...

# %%
modeling(X_train, X_test, Y_train, Y_test)
# Out:
# Accuracy of LogisticRegression Model: 0.5772058823529411
# Accuracy of DecisionTree Model: 0.4963235294117647
# Visualize Feature Importance:

# %%
# Making binary classificaion
x_train, x_test, y_train, y_test = binary_classificaion(wine_df)

# %%
# Random Forests
Random_Forests(x_train, x_test, y_train, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       238
#            1       0.74      0.41      0.53        34
#
#     accuracy                           0.91       272
#    macro avg       0.83      0.70      0.74       272
# weighted avg       0.90      0.91      0.90       272
#
# Accuracy of Random Forests Model: 90.80882352941177
# Visualize Feature Importance:

# %% [markdown]
# # Section 3 - Visualization

# %%
import seaborn as sns

corrMatrix = wine_df.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corrMatrix, annot=True)
plt.title('Correlation Matrix of Red wine')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data = wine_df, x = 'quality', palette = "rocket")
plt.title('Distribution of Quality')
# Out:
# Text(0.5, 1.0, 'Distribution of Quality')

# %%
plt.figure(figsize=(12, 8))
sns.histplot(data = wine_df, x = 'alcohol', color = 'tab:orange', kde = True, bins=25)
plt.title('Distribution of Alcohol')
# Out:
# Text(0.5, 1.0, 'Distribution of Alcohol')
